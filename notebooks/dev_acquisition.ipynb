# %% [markdown]
# ### Acquisition methos

# %%
# Import pandas 
import pandas as pd
import requests

# %%
path1 = '../data/bicimad_stations.csv'
df1 = pd.read_csv(path1, sep= "	")
#df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 path1 = '../data/bicimad_stations.csv'
# ----> 2 df1 = pd.read_csv(path1, sep= "	")
#
# File ~\AppData\Local\anaconda3\envs\m1\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
path2 = '../data/bicipark_stations.csv'
df2 = pd.read_csv(path2, sep= ";")
#df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 path2 = '../data/bicipark_stations.csv'
# ----> 2 df2 = pd.read_csv(path2, sep= ";")
#
# File ~\AppData\Local\anaconda3\envs\m1\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#Acceder a la API 
# Main End-Point
end_point = 'https://datos.madrid.es/egob'
#Body
par1 = '/catalogo/300614-0-centros-educativos.json'

url = end_point + par1
url
# Out:
# 'https://datos.madrid.es/egob/catalogo/300614-0-centros-educativos.json'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
json_data = response.json()
print(len(json_data))
# Out:
# 2

# %%
json_data.keys()
# Out:
# dict_keys(['@context', '@graph'])

# %%
print(type(json_data['@context']))
print(type(json_data['@graph']))
# Out:
# <class 'dict'>
# <class 'list'>

# %%
json_data['@graph']
# Out:
# [{'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/4916066-abc-schule-aleman-.json',
#   'id': '4916066',
#   'title': 'ABC Schule (Alemán)',
#   'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=d167e229b31f9110VgnVCM2000000c205a0aRCRD',
#   'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamartin'},
#    'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamartin/Barrio/ElViso'},
#    'locality': 'MADRID',
#    'postal-code': '28002',
#    'street-address': 'CALLE LEIZARAN 27'},
#   'location': {'latitude': 40.44793196689411,
#    'longitude': -3.6813824984159287},
#   'organization': {'organization-desc': '\xa0EDUCACIÓN: Infantil Primer y segundo ciclo  IDIOMA: Alemán\xa0BUS: 7, 16, 19, 29, 51, 52 METRO: Cruz del Rayo, Príncipe de Vergara',
#    'accesibility': '0',
#    'schedule': '',
# ...

# %%
json_data['@context']
# Out:
# {'c': 'http://www.w3.org/2002/12/cal#',
#  'dcterms': 'http://purl.org/dc/terms/',
#  'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#  'loc': 'http://purl.org/ctic/infraestructuras/localizacion#',
#  'org': 'http://purl.org/ctic/infraestructuras/organizacion#',
#  'vcard': 'http://www.w3.org/2006/vcard/ns#',
#  'schema': 'https://schema.org/',
#  'title': 'vcard:fn',
#  'id': 'dcterms:identifier',
#  'relation': 'dcterms:relation',
#  'references': 'dcterms:references',
#  'address': 'vcard:adr',
#  'area': 'loc:barrio',
#  'district': 'loc:distrito',
#  'locality': 'vcard:locality',
#  'postal-code': 'vcard:postal-code',
#  'street-address': 'vcard:street-address',
#  'location': 'vcard:geo',
#  'latitude': 'geo:lat',
#  'longitude': 'geo:long',
#  'organization': 'vcard:org',
#  'organization-desc': 'dcterms:description',
#  'accesibility': 'org:accesibilidad',
#  'services': 'org:servicios',
#  'schedule': 'org:horario',
#  'organization-name': 'vcard:organization-name',
# ...

# %%
for i in json_data['@context'].keys():
    print(json_data['@context'][i])
# Out:
# http://www.w3.org/2002/12/cal#
# http://purl.org/dc/terms/
# http://www.w3.org/2003/01/geo/wgs84_pos#
# http://purl.org/ctic/infraestructuras/localizacion#
# http://purl.org/ctic/infraestructuras/organizacion#
# http://www.w3.org/2006/vcard/ns#
# https://schema.org/
# vcard:fn
# dcterms:identifier
# dcterms:relation
# dcterms:references
# vcard:adr
# loc:barrio
# loc:distrito
# vcard:locality
# vcard:postal-code
# vcard:street-address
# vcard:geo
# geo:lat
# geo:long
# vcard:org
# dcterms:description
# org:accesibilidad
# org:servicios
# org:horario
# vcard:organization-name
# c:summary
# c:url
# c:uid
# c:dtstart
# c:dtend
# c:time
# c:exdate
# c:location
# schema:free
# c:resource
# c:rrule
# c:byday
# c:freq
# c:interval
# dc:audience
